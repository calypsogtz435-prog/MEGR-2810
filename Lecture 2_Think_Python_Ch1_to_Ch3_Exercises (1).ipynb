# %% [markdown]
# ## Arithmetic Operators

# %%
# Arithmetic Operators
# Python supports basic arithmetic operations:
# Addition (+), Subtraction (-), Multiplication (*), Division (/), Modulus (%), Exponentiation (**)

a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", b - a) # Your code from here and on 
print("Multiplication:", a * b )
print("Division:", b/a )
print("Floor Division:", b/a)
print("Modulus:", a % b) # Modulus operator gives the remainder
print("Exponentiation:", a ** b )
# Out:
# Addition: 13
# Subtraction: -7
# Multiplication: 30
# Division: 0.3
# Floor Division: 0.3
# Modulus: 1
# Exponentiation: 1000

# %% [markdown]
# ## Expressions

# %%
# Expressions
# An expression is a combination of values, variables, and operators that Python can evaluate.

x = 5
y = 2
a = x * (y + 3) # Your code to change a and b to different expressions
b = x * y + 3
c = y + 7 + (x**3)
d = y ** 2 + x
print("Expression result: a =", a, " b =", b, "c =", c , "d =", d)
# Out:
# Expression result: a = 25  b = 13 c = 134 d = 9

# %% [markdown]
# ## Arithmetic Functions

# %%
# Arithmetic Functions
# Python provides built-in functions like round() and abs()

value = -7.89627

print("Absolute value:", abs(value))
print("Rounded value:", round(value, 3))

# Your code here
value2 = -23.576
print ("Absolute value:", abs(value2))
print ("Rounded value:", round(value2, 1))
# Out:
# Absolute value: 7.89627
# Rounded value: -7.896
# Absolute value: 23.576
# Rounded value: -23.6

# %% [markdown]
# ## Strings

# %%
# Strings
# Strings are sequences of characters enclosed in quotes.

greeting1 = "Hello, World!"
greeting2 = 'Hello' + ', ' + "World!"
print(greeting1)
print(greeting2)
print("Length of string 1:", len(greeting1))
print("Uppercase:", greeting2.upper())

# Your code here
greeting3 = "Hello, my name is Calypso!"
print (greeting3)
print ("Length of string 3:", len(greeting3))
print ("Uppercase:" , greeting3.upper())
# Out:
# Hello, World!
# Hello, World!
# Length of string 1: 13
# Uppercase: HELLO, WORLD!
# Hello, my name is Calypso!
# Length of string 3: 26
# Uppercase: HELLO, MY NAME IS CALYPSO!

# %% [markdown]
# ## Values and Variables

# %%
# Values and Variables
# Variables store values. Use type() to check the type of a value.

num = 42
text = "Python"
int_num = int("123")

print("Type of num:", type(num))
print("Type of text:", type(text))
print("Convert string to int:", int("123"))
print("Convert string to float:", float("123.456"))
print("Convert float to int:", int(123.456))

# Your code here
num2 = 50
text2 = "nugget"
int_num2 = int ("226")
print ("Type of num:", type (num2))
print ("Type of text:", type (text2))
print ("convert string to int:", int ("226"))
print ("convert string to float:", float ("257.226"))
print ("Convert float to int:", int (257.226))
# Out:
# Type of num: <class 'int'>
# Type of text: <class 'str'>
# Convert string to int: 123
# Convert string to float: 123.456
# Convert float to int: 123
# Type of num: <class 'int'>
# Type of text: <class 'str'>
# convert string to int: 226
# convert string to float: 257.226
# Convert float to int: 257

# %% [markdown]
# ## Variable Assignments and Statements

# %%
# Variable Assignments and Statements
# Use = to assign values to variables.

x = 10
y = x + 5
print("Value of y:", y)
# Out:
# Value of y: 15

# %% [markdown]
# ## Variable Naming Rules and Keywords

# %%
# Variable Naming Rules and Keywords
# Variable names must start with a letter or underscore and cannot be Python keywords.

# Valid variable names
my_var = 1
_var2 = 2

# Invalid: 2var = 3 (starts with a number)
# Invalid: if = 4 (if is a keyword)

import keyword
print("Python keywords:", keyword.kwlist) # Print out a list of Python keywords
# Out:
# Python keywords: ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## Math Module

# %%
# Math Module
# Import the math module to access mathematical functions

import math

print("Square root of 16:", math.sqrt(16))
print("Value of pi:", math.pi)
print("Cosine of 0:", math.cos(0))

# Your code here to use math functions. Do what you like!
# Out:
# Square root of 16: 4.0
# Value of pi: 3.141592653589793
# Cosine of 0: 1.0

# %% [markdown]
# ## TypeErrors

# %%
# TypeErrors
# TypeErrors occur when operations are applied to incompatible types

# Example:
try:
    result = "hello" + 5
except TypeError as e:
    print("TypeError:", e)

# Fix the error
# Out:
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Comments

# %%
# Comments
# Use comments to explain code. Comments start with #

# This is a comment
x = 5  # Assign 5 to x
print(x) # Will print the value of x variable
# Out:
# 5

# %% [markdown]
# # Exercises
# # Try these:
# # 1. Create a variable and assign it a string.
# # 2. Use math.sqrt() to find the square root of a number.
# # 3. Write a comment explaining what your code does.

# %%
# Code here
z = "chicken nugget"
print(z)
# Out:
# chicken nugget

# %%
# Code here
import math
math.sqrt(36)
# Out:
# 6.0

# %%
# variable a and b are labeled, now you can use any arithmetic operations by using a and b
a = 6
b = 7
b * a
# Out:
# 42

# %% [markdown]
# ## Functions

# %%
# Functions
# Functions are reusable blocks of code defined using def

def greet():
    print("Hello from a function!")

greet()

# Your code here to define and call more functions
def goodbye():
    print ("I hope you have a great day!") 
    print ("Can't wait to see you again.") 
    print (2+2, "haha" + " " + "see what I did there?")
goodbye()
# Out:
# Hello from a function!
# I hope you have a great day!
# Can't wait to see you again.
# 4 haha see what I did there?

# %% [markdown]
# ## Parameters and Arguments

# %%
# Parameters and Arguments
# Functions can accept parameters

def greet(name):
    print("Hello", name)

greet("Alice")

# Your code here to define and call functions with parameters
def farewell(name):
    print("see you soon!", name)
farewell("Chicken haha")
# Out:
# Hello Alice
# see you soon! Chicken haha

# %% [markdown]
# ## Calling Functions and Local Variables

# %%
# Calling Functions and Local Variables
# Variables inside functions are local to that function

def add(a, b):
    result = a + b
    return result

print("Sum:", add(3, 4))

print(add(a, b))  # This will raise an error because result is local to add()

# Your code here to define and call more functions with local variables
def subtract (c, d):
    result = d - c
    return result
print ("Subtraction:", subtract (25, 10))

print (subtract (c, d))
# Out:
# Sum: 7
# 13
# Subtraction: -15
# -125

# %% [markdown]
# ## Loops

# %%
# Loops
# Use for loops to repeat actions

for i in range(5):
    print("Iteration", i)

# Your code here to define and use more loops
for k in range (4):
    print ("I am Hungry!",k)
    print ("I want a big burrito, extra meat")
# Out:
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# I am Hungry! 0
# I want a big burrito, extra meat
# I am Hungry! 1
# I want a big burrito, extra meat
# I am Hungry! 2
# I want a big burrito, extra meat
# I am Hungry! 3
# I want a big burrito, extra meat

# %% [markdown]
# # Loop Through a List
# Loop through a list of forces and calculate stress using σ = F / A. Flag any stress that exceeds the yield limit.

# %%
forces = [500, 1000, 1500, 2000, 2500, 3000, 3500]  # in Newtons
area = 0.255  # cross-sectional area in m²
yield_limit = 365000  # in Pascals

for F in forces:
    stress = F / area
    status = "OK"
    if stress > yield_limit:
        status = "Exceeds yield limit!"
    print(f"Force: {F} N → Stress: {stress:.2f} Pa → {status}")

# Modify the code above to add more forces and change area and yield_limit
# Out:
# Force: 500 N → Stress: 1960.78 Pa → OK
# Force: 1000 N → Stress: 3921.57 Pa → OK
# Force: 1500 N → Stress: 5882.35 Pa → OK
# Force: 2000 N → Stress: 7843.14 Pa → OK
# Force: 2500 N → Stress: 9803.92 Pa → OK
# Force: 3000 N → Stress: 11764.71 Pa → OK
# Force: 3500 N → Stress: 13725.49 Pa → OK

# %% [markdown]
# # Print Text

# %%
text = "Five Lemonades"
print(text[:10]) # NameError: name 'text' is not defined. Need to define 'text' first.
# Fix the error
# Out:
# Five Lemon

# %% [markdown]
# # Final Exercises
# # 1. Write a function that returns the square of a number.
# # 2. Use a loop to print numbers from 1 to 10.
# # 3. Use round() and abs() in a function.

# %%
# Code here
def square_number (num):
    return num ** 3
print (square_number (5))
# Out:
# 125

# %%
# Code here
for d in range (1 , 11):
    print ("27 + 28", d)
# Out:
# 27 + 28 1
# 27 + 28 2
# 27 + 28 3
# 27 + 28 4
# 27 + 28 5
# 27 + 28 6
# 27 + 28 7
# 27 + 28 8
# 27 + 28 9
# 27 + 28 10

# %%
# Code here
b = 27.567 + 37.23
print (abs(b), round(b,2))
# Out:
# 64.797 64.8
