# %% [markdown]
# Question 2: Which of the following is a valid variable assignment?

# %%
age = 25 #all other options are invalid
 # previously chosen answer was "lambda = 0.001" which has a syntax error

# %% [markdown]
# Question 15: What is the output of this code?

# %%
def square(x): 
    result = x**2
    return result
print(square(5)) #mistook the code for attempting to take a square root not squaring a number
# Out:
# 25

# %% [markdown]
# Question 19: How do you format a float to 2 decimal places in a print statement?

# %%
import math
pi = math.pi
print(f"{pi:.2f}") #was simply unfamiliar with this formatting syntax
# Out:
# 3.14
